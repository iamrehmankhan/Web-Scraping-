# %%
#import modules and packages
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import numpy as np

# %%
#scrap the single game shots
base_url = 'https://understat.com/match/'
match = str(input('Please enter match id:  '))
url = base_url + match
# Out:
# Please enter match id:  14809

# %%
url
# Out:
# 'https://understat.com/match/14809'

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
# ...

# %%
#get only the shots data
strings = scripts[1].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22424025\\x22,\\x22minute\\x22\\x3A\\x228\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.9169999694824219\\x22,\\x22Y\\x22\\x3A\\x220.4\\x22,\\x22xG\\x22\\x3A\\x220.03564458712935448\\x22,\\x22player\\x22\\x3A\\x22Caglar\\x20S\\x5Cu00f6y\\x5Cu00fcnc\\x5Cu00fc\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x225264\\x22,\\x22situation\\x22\\x3A\\x22FromCorner\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22Head\\x22,\\x22match_id\\x22\\x3A\\x2214809\\x22,\\x22h_team\\x22\\x3A\\x22Leicester\\x22,\\x22a_team\\x22\\x3A\\x22Tottenham\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x224\\x22,\\x22date\\x22\\x3A\\x222021\\x2D05\\x2D23\\x2015\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Youri\\x20Tielemans\\x22,\\x22lastAction\\x22\\x3A\\x22Cross\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22424026\\x22,\\x22minute\\x22\\x3A\\x2210\\x22,
# ...

# %%
#strip symbols so we only have the json data
ind_start = strings.index("('")+2
ind_end = strings.index("')")

json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '424025',
#    'minute': '8',
#    'result': 'SavedShot',
#    'X': '0.9169999694824219',
#    'Y': '0.4',
#    'xG': '0.03564458712935448',
#    'player': 'Caglar Söyüncü',
#    'h_a': 'h',
#    'player_id': '5264',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'Head',
#    'match_id': '14809',
#    'h_team': 'Leicester',
#    'a_team': 'Tottenham',
#    'h_goals': '2',
#    'a_goals': '4',
#    'date': '2021-05-23 15:00:00',
#    'player_assisted': 'Youri Tielemans',
#    'lastAction': 'Cross'},
#   {'id': '424026',
#    'minute': '10',
#    'result': 'BlockedShot',
#    'X': '0.7559999847412109',
#    'Y': '0.664000015258789',
#    'xG': '0.018925316631793976',
#    'player': 'James Maddison',
#    'h_a': 'h',
#    'player_id': '6818',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14809',
#    'h_team': 'Leicester',
#    'a_team': 'Tottenham',
#    'h_goals': '2',
#    'a_goals': '4',
# ...

# %%
x = []
y = []
xg = []
team = []
data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'xG':
            xg.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
            
for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'xG':
            xg.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])

# %%
#create the actual dataframe

col_names = ['x(Distance along x-axis)','y(Distance along y-axis)','xG(Expected Goal)','team']
df = pd.DataFrame([x,y,xg,team],index=col_names)
df
# Out:
#                                            0                     1   \
# x(Distance along x-axis)   0.9169999694824219    0.7559999847412109
# y(Distance along y-axis)                  0.4     0.664000015258789
# xG(Expected Goal)         0.03564458712935448  0.018925316631793976
# team                                Leicester             Leicester
#
#                                           2                    3   \
# x(Distance along x-axis)               0.885   0.7480000305175781
# y(Distance along y-axis)                 0.5  0.38599998474121094
# xG(Expected Goal)         0.7611688375473022  0.02470560185611248
# team                               Leicester            Leicester
#
#                                            4                    5   \
# x(Distance along x-axis)   0.9059999847412109                 0.74
# y(Distance along y-axis)   0.3509999847412109   0.6229999923706054
# xG(Expected Goal)         0.06672249734401703  0.02057606726884842
# ...

# %%
dict1= {
    "Team A(Leicester)":['Player1','Player2','Player3','Player4','Player5','Player6','Player7','Player8','Player9','Player10','Player11'],
    "xG(Expected Goal)":['0.03','0.01','0.76','0.02','0.06','0.02','0.76','0.04','0','0.02','0.06'],
    "y(Distance along y-axis)":['0.40','0.66','0.5','0.38','0.35','0.62','0.5','0.6','0.4','0.69','0.42'],
    "x(Distance along x-axis)":['0.91','0.75','0.88','0.74','0.90','0.74','0.88','0.88','0.02','0.77','0.93'],
}

# %%
pd.DataFrame(dict1)
# Out:
#    Team A(Leicester) xG(Expected Goal) y(Distance along y-axis)  \
# 0            Player1              0.03                     0.40
# 1            Player2              0.01                     0.66
# 2            Player3              0.76                      0.5
# 3            Player4              0.02                     0.38
# 4            Player5              0.06                     0.35
# 5            Player6              0.02                     0.62
# 6            Player7              0.76                      0.5
# 7            Player8              0.04                      0.6
# 8            Player9                 0                      0.4
# 9           Player10              0.02                     0.69
# 10          Player11              0.06                     0.42
#
#    x(Distance along x-axis)
# 0                      0.91
# 1                      0.75
# 2                      0.88
# 3                      0.74
# 4                      0.90
# ...

# %%
dict2 = {
    "Team B(Tottenham)":['Player1','Player2','Player3','Player4','Player5','Player6','Player7','Player8','Player9','Player10','Player11'],
    "xG(Expected Goal)":['0.02','0.02','0.02','0.48','0.05','0.07','0.02','0.08','0.14','0.53','0.80'],
    "y(Distance along y-axis)":['0.71','0.62','0.68','0.53','0.53','0.66','0.65','0.52','0.44','0.50','0.48'],
    "x(Distance along x-axis)":['0.84','0.96','0.81','0.91','0.83','0.90','0.80','0.85','0.89','0.91','0.97'],
}

# %%
pd.DataFrame(dict2)
# Out:
#    Team B(Tottenham) xG(Expected Goal) y(Distance along y-axis)  \
# 0            Player1              0.02                     0.71
# 1            Player2              0.02                     0.62
# 2            Player3              0.02                     0.68
# 3            Player4              0.48                     0.53
# 4            Player5              0.05                     0.53
# 5            Player6              0.07                     0.66
# 6            Player7              0.02                     0.65
# 7            Player8              0.08                     0.52
# 8            Player9              0.14                     0.44
# 9           Player10              0.53                     0.50
# 10          Player11              0.80                     0.48
#
#    x(Distance along x-axis)
# 0                      0.84
# 1                      0.96
# 2                      0.81
# 3                      0.91
# 4                      0.83
# ...
